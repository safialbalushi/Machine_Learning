# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_openml

# %%
features = (np.random.random([30, 2])* 20) - 10

# %%
x = pd.DataFrame(features, columns = ['f1','f2'])
y = label
print(x.head())
#print(y.dtypes)
# Out:
#          f1        f2
# 0 -4.223295  5.858741
# 1  4.807735 -5.502450
# 2 -3.288513  1.114602
# 3  4.081084 -6.487159
# 4 -2.578313 -1.301211

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (22, 2)
# (8, 2)
# (22,)
# (8,)

# %%
#training and testing model

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lin_model = LinearRegression()
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
# model evaluation for training set
y_train_predict = lin_model.predict(x_train)
testPred = lin_model.predict(x_test)
rmse = (np.sqrt(mean_squared_error(y_train, y_train_predict)))
r2 = r2_score(y_train, y_train_predict)
print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# model evaluation for testing set
y_test_predict = lin_model.predict(x_test)
rmse = (mean_squared_error(y_test, y_test_predict))
r2 = r2_score(y_test, y_test_predict)
print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 10.516679490870375
# R2 score is 0.1768203897025422
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 345.6270646575515
# R2 score is 0.05156354868851443

# %%
#plot graph to see
plt.scatter(x_train['f1'], y_train,color='g') 
plt.scatter(x_train['f2'], y_train,color='y') 
plt.plot(x_test['f1'], y_test_predict,color='b') 
plt.plot(x_test['f2'], y_test_predict,color='r')
plt.title('SAFIA /*/ 51919')
plt.show()

# %%
plt.scatter(x_test['f1'],y_test)
plt.scatter(x_test['f2'],y_test_predict)
plt.title('SAFIA / 51919')
plt.show()

# %%
from sklearn.datasets import load_boston
from sklearn.datasets import fetch_openml

housing = fetch_openml(name="house_prices", as_frame=True)

# %%
print(housing.keys())
# Out:
# dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])

# %%
housing.target
# Out:
# 0       208500.0
# 1       181500.0
# 2       223500.0
# 3       140000.0
# 4       250000.0
#           ...
# 1455    175000.0
# 1456    210000.0
# 1457    266500.0
# 1458    142125.0
# 1459    147500.0
# Name: SalePrice, Length: 1460, dtype: float64

# %%
housing.data
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  None      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  None      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  None      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  None      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  None      Reg
#
# ...

# %%
#making Data frame From Given data
housing_df=pd.DataFrame(housing.data,columns=housing.feature_names)
housing_df.head
# Out:
# <bound method NDFrame.head of           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  None      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  None      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  None      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  None      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  None      Reg
#
# ...

# %%
# Adding targeted value in dataset
housing_df['price']=housing.target
housing_df.head
# Out:
# <bound method NDFrame.head of           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  None      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  None      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  None      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  None      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  None      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  None      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  None      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  None      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  None      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  None      Reg
#
# ...

# %%
housing_df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# price              0
# Length: 81, dtype: int64

# %%
#Printing Data types 
housing_df=housing_df.dropna(1)
print(housing_df.dtypes)
# Out:
# Id               float64
# MSSubClass       float64
# MSZoning          object
# LotArea          float64
# Street            object
#                   ...
# MoSold           float64
# YrSold           float64
# SaleType          object
# SaleCondition     object
# price            float64
# Length: 62, dtype: object
# C:\Temp/ipykernel_6268/3545157173.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   housing_df=housing_df.dropna(1)

# %%
#Ploting a graph using seboarn library
sns.set(rc={'figure.figsize':(12,8)})
sns.distplot(housing_df['price'], bins=12)
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Plot Heatmap graph and corellationmatrix
correlation_matrix = housing_df.corr().round(2)
print(correlation_matrix)
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
#                  Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# Id             1.00        0.01    -0.03        -0.03         0.01      -0.01
# MSSubClass     0.01        1.00    -0.14         0.03        -0.06       0.03
# LotArea       -0.03       -0.14     1.00         0.11        -0.01       0.01
# OverallQual   -0.03        0.03     0.11         1.00        -0.09       0.57
# OverallCond    0.01       -0.06    -0.01        -0.09         1.00      -0.38
# YearBuilt     -0.01        0.03     0.01         0.57        -0.38       1.00
# YearRemodAdd  -0.02        0.04     0.01         0.55         0.07       0.59
# BsmtFinSF1    -0.01       -0.07     0.21         0.24        -0.05       0.25
# BsmtFinSF2    -0.01       -0.07     0.11        -0.06         0.04      -0.05
# BsmtUnfSF     -0.01       -0.14    -0.00         0.31        -0.14       0.15
# TotalBsmtSF   -0.02       -0.24     0.26         0.54        -0.17       0.39
# ...

# %%
# OverallCond','YearBuilt'

#lets plot these

plt.figure(figsize=(20, 5))

features = ['OverallCond','YearBuilt']
target = housing_df['price']

for i, col in enumerate(features):
    plt.subplot(1, len(features) , i+1)
    a = housing_df[col]
    b = target
    plt.scatter(a, b, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('price')

# %%
housing_df.isna().values.any()
housing_df.isnull().values.any()
housing_df = housing_df.dropna()
print(housing_df.isnull().values.any())
# Out:
# False

# %%
#dividing into  X and Y
X = pd.DataFrame(np.c_[housing_df['OverallCond'], housing_df['YearBuilt']], columns = ['OverallCoud','YearBuilt'])
y = housing_df['price']
print(X.dtypes)
print(y.dtypes)
# Out:
# OverallCoud    float64
# YearBuilt      float64
# dtype: object
# float64

# %%
#Now dividing into test and train 
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, y)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (1095, 2)
# (365, 2)
# (1095,)
# (365,)

# %%
# Now training and testing model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
lin_model = LinearRegression()
lin_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
# model evaluation for training set
y_train_predict = lin_model.predict(X_train)
testPred = lin_model.predict(X_test)
rmse = (np.sqrt(mean_squared_error(Y_train, y_train_predict)))
r2 = r2_score(Y_train, y_train_predict)

print("The model performance for training set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")

# model evaluation for testing set
y_test_predict = lin_model.predict(X_test)
rmse = (mean_squared_error(Y_test, y_test_predict))
r2 = r2_score(Y_test, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# RMSE is 66188.90413996608
# R2 score is 0.2854895777863573
#
#
# The model performance for testing set
# --------------------------------------
# RMSE is 4785211001.673392
# R2 score is 0.29958690674426525

# %%
#plot to see graph
plt.scatter(X_train['OverallCoud'], Y_train,color='k') 
#plt.scatter(X_train['YearBuilt'], Y_train,color='g') 
plt.plot(X_test['OverallCoud'], y_test_predict,color='b') 
#plt.plot(X_test['YearBuilt'], y_test_predict,color='r')
plt.title('SAFIA / 51919')
plt.show()

# %%
plt.scatter(X_test['OverallCoud'],Y_test)
plt.scatter(X_test['OverallCoud'],y_test_predict)
#plt.scatter(X_test['YearBuilt'],Y_test)
#plt.scatter(X_test['YearBuilt'],y_test_predict)
plt.title('SAFIA / 51919')
plt.show()
